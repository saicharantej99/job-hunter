# %% [markdown]
# <h1>Web Scraping Indeed for Key Data Science Job Skills </h1>

# %% [markdown]
# # Cleaning a Website

# %%
from bs4 import BeautifulSoup # For HTML parsing
import urllib.request # Website connections
import re # Regular expressions
from time import sleep # To prevent overwhelming the server between connections
from collections import Counter # Keep track of our term counts
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd # For converting results to a dataframe and bar chart plots
# %matplotlib inline

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# Now create our first website parsing function

# %%
def text_cleaner(website):
    '''
    This function just cleans up the raw html so that I can look at it.
    Inputs: a URL to investigate
    Outputs: Cleaned text only
    '''
    try:
        site = urllib.request.urlopen(website).read() # Connect to the job posting
    except: 
        return   # Need this in case the website isn't there anymore or some other weird connection problem 
    
    soup_obj = BeautifulSoup(site) # Get the html from the site
    
    for script in soup_obj(["script", "style"]):
        script.extract() # Remove these two elements from the BS4 object
    
    

    text = soup_obj.get_text() # Get the text from this
    
        
    
    lines = (line.strip() for line in text.splitlines()) # break into lines
    
        
        
    chunks = (phrase.strip() for line in lines for phrase in line.split("  ")) # break multi-headlines into a line each
    
    def chunk_space(chunk):
        chunk_out = chunk + ' ' # Need to fix spacing issue
        return chunk_out  
        
    
    text = ''.join(chunk_space(chunk) for chunk in chunks if chunk).encode('utf-8') # Get rid of all blank lines and ends of line
        
        
    # Now clean out all of the unicode junk (this line works great!!!)
        
    try:
        text = text.decode('unicode_escape').encode('ascii', 'ignore') # Need this as some websites aren't formatted
    except:                                                            # in a way that this works, can occasionally throw
        return                                                         # an exception
       
        
    text = re.sub("[^a-zA-Z.+3]"," ", text.decode('utf-8'))  # Now get rid of any terms that aren't words (include 3 for d3.js)
                                                # Also include + for C++
        
       
    text = text.lower().split()  # Go to lower case and split them apart
        
        
    stop_words = set(stopwords.words("english")) # Filter out any stop words
    text = [w for w in text if not w in stop_words]
        
        
        
    text = list(set(text)) # Last, just get the set of these. Ignore counts (we are just looking at whether a term existed
                            # or not on the website)
        
    return text

# %%
sample = text_cleaner('https://www.indeed.co.in/viewjob?jk=76a15d792ddb6cc0&tk=1ebvkckfp154h000&from=serp&vjs=3')
print (sample[:20])
# Out:
# ['cassandra', 'regard', 'strategic', 'faire', 'consideration', 'distributions', 'highest', 'developing', 'age', 'national', 'handicap', 'speaking', 'fiers', 'management', 'seven', 'model', 'investment', 'sg', 'years', 'nadujobs']

# %% [markdown]
# As you can see in the code above, a lot of cleaning for the raw html is necessary to get the final terms we are looking for. It extracts the relevant portions of the html, gets the text, removes blank lines and line endings, removes unicode, and filters with regular expressions to include only words. To see what the final result looks like, let’s try calling this function on a sample job posting.

# %% [markdown]
# # Accessing the Job Postings

# %%
def skills_info_ind(city = None, state = None):
    '''
    This function will take a desired city/state and look for all new job postings
    on Indeed.com. It will crawl all of the job postings and keep track of how many
    use a preset list of typical data science skills. The final percentage for each skill
    is then displayed at the end of the collation. 
        
    Inputs: The location's city and state. These are optional. If no city/state is input, 
    the function will assume a national search (this can take a while!!!).
    Input the city/state as strings, such as skills_info('Chicago', 'IL').
    Use a two letter abbreviation for the state.
    
    Output: A bar chart showing the most commonly desired skills in the job market for 
    a data scientist. 
    '''
        
    final_job = 'data+scientist' # searching for data scientist exact fit("data scientist" on Indeed search)
    
    # Make sure the city specified works properly if it has more than one word (such as San Francisco)
    if city is not None:
        final_city = city.split() 
        final_city = '+'.join(word for word in final_city)
        final_site_list = ['http://www.indeed.co.in/jobs?q=%22', final_job, '%22&l=', final_city,
                    '%2C+', state] # Join all of our strings together so that indeed will search correctly
    else:
        final_site_list = ['http://www.indeed.co.in/jobs?q="', final_job, '"']

    final_site = ''.join(final_site_list) # Merge the html address together into one string
    print (final_site)
    
    base_url = 'http://www.indeed.co.in'
    
    
    try:
        html = urllib.request.urlopen(final_site).read() # Open up the front page of our search first
    except:
        'That city/state combination did not have any jobs. Exiting . . .' # In case the city is invalid
        return
    soup = BeautifulSoup(html) # Get the html from the first page
    
    # Now find out how many jobs there were
    
    num_jobs_area = soup.find(id = 'searchCountPages').string.encode('utf-8') # Now extract the total number of jobs found
                                                                        # The 'searchCount' object has this
    print (num_jobs_area)
    job_numbers = re.findall('\d+', num_jobs_area.decode('utf-8')) # Extract the total jobs found from the search result
    print (job_numbers)
    
    if len(job_numbers) > 1: # Have a total number of jobs greater than 1000
        total_num_jobs = (int(job_numbers[1])*10)
    else:
        total_num_jobs = int(job_numbers[0]) 
    
    city_title = city
    if city is None:
        city_title = 'Nationwide'
        
    print ('There were', total_num_jobs, 'jobs found,', city_title) # Display how many jobs were found
    
    num_pages = total_num_jobs/10 # This will be how we know the number of times we need to iterate over each new
                                      # search result page
    job_descriptions = [] # Store all our descriptions in this list
    
    for i in range(1,int(num_pages)+1): # Loop through all of our search result pages
        print ('Getting page', i)
        start_num = str(i*10) # Assign the multiplier of 10 to view the pages we want
        current_page = ''.join([final_site, '&start=', start_num])
        # Now that we can view the correct 10 job returns, start collecting the text samples from each
            
        html_page = urllib.request.urlopen(current_page).read() # Get the page
            
        page_obj = BeautifulSoup(html_page) # Locate all of the job links
        job_link_area = page_obj.find(id = 'resultsCol') # The center column on the page where the job postings exist
            
        
        for link in job_link_area.find_all('a'):
            if link.get('href') is not None:
                job_URLS = [base_url + link.get('href')]
         
        job_URLS = [base_url + link.get('href') for link in job_link_area.find_all('a') if link.get('href') is not None ] # Get the URLS for the jobs
        job_URLS = list(filter(lambda x:'clk' in x, job_URLS)) # Now get just the job related URLS
        print (job_URLS)    
        
        for j in range(0,len(job_URLS)):
            final_description = text_cleaner(job_URLS[j])
            if final_description: # So that we only append when the website was accessed correctly
                job_descriptions.append(final_description)
            sleep(1) #If you have a very fast internet connection you could hit the server a lot! 
    print (job_descriptions)    
    print ('Done with collecting the job postings!')    
    print ('There were', len(job_descriptions), 'jobs successfully found.')
    
    
    doc_frequency = Counter() # This will create a full counter of our terms. 
    [doc_frequency.update(item) for item in job_descriptions] # List comp
    
    # Now we can just look at our final dict list inside doc_frequency
    
    # Obtain our key terms and store them in a dict. These are the key data science skills we are looking for
    
    prog_lang_dict = Counter({'R':doc_frequency['r'], 'Python':doc_frequency['python'],
                    'Java':doc_frequency['java'], 'C++':doc_frequency['c++'],
                    'Ruby':doc_frequency['ruby'],
                    'Perl':doc_frequency['perl'], 'Matlab':doc_frequency['matlab'],
                    'JavaScript':doc_frequency['javascript'], 'Scala': doc_frequency['scala']})
                      
    analysis_tool_dict = Counter({'Excel':doc_frequency['excel'],  'Tableau':doc_frequency['tableau'],
                        'D3.js':doc_frequency['d3.js'], 'SAS':doc_frequency['sas'],
                        'SPSS':doc_frequency['spss'], 'D3':doc_frequency['d3']})  

    hadoop_dict = Counter({'Hadoop':doc_frequency['hadoop'], 'MapReduce':doc_frequency['mapreduce'],
                'Spark':doc_frequency['spark'], 'Pig':doc_frequency['pig'],
                'Hive':doc_frequency['hive'], 'Shark':doc_frequency['shark'],
                'Oozie':doc_frequency['oozie'], 'ZooKeeper':doc_frequency['zookeeper'],
                'Flume':doc_frequency['flume'], 'Mahout':doc_frequency['mahout']})
                
    database_dict = Counter({'SQL':doc_frequency['sql'], 'NoSQL':doc_frequency['nosql'],
                    'HBase':doc_frequency['hbase'], 'Cassandra':doc_frequency['cassandra'],
                    'MongoDB':doc_frequency['mongodb']})
    
    skill_dict = Counter({'Analytics':doc_frequency['analytics'], 'Hadoop':doc_frequency['hadoop'],'ML':doc_frequency['machine'],
                    'Data Mining':doc_frequency['mining'], 'Visualization':doc_frequency['visualization'],'NLP':doc_frequency['language'],'Computer Vision':doc_frequency['vision'],'Deep Learning':doc_frequency['deep'],'Graph Engine':doc_frequency['graph'] })

    domain_dict = Counter({'Aerospace':doc_frequency['aerospace'], 'Automobile':doc_frequency['automobile'],
                    'Banking':doc_frequency['banking'], 'FMCG':doc_frequency['fmcg'],
                    'Retail':doc_frequency['retail'],'Travel':doc_frequency['travel'],'Telecom':doc_frequency['telecom'],'Healthcare':doc_frequency['healthcare'], 'Energy':doc_frequency['energy'],'Education':doc_frequency['education']})                 
               
    #overall_total_skills = prog_lang_dict + analysis_tool_dict + database_dict + skill_dict # Combine our Counter objects
    overall_total_skills = domain_dict # Combine our Counter objects
    print (overall_total_skills)    
    
    columns = ['Term', 'NumPostings']
    final_frame = pd.DataFrame.from_dict(overall_total_skills,orient='index').reset_index() # Convert these terms to a 
                                                                                                # dataframe 
    final_frame = final_frame.rename(columns={'index':'Term', 0:'NumPostings'})
    
    # Change the values to reflect a percentage of the postings 
    
    print (final_frame)
    final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings 
                                                                                    #  having that term 
    
    # Sort the data for plotting purposes
    
    final_frame.sort_values(by = 'NumPostings', ascending = False, inplace = True)
    
    # Get it ready for a bar plot
    print ('****')    
    print (final_frame)
    print ('Sai')
    state = "Silicon Valley"
    final_plot = final_frame.plot(x = 'Term', kind = 'bar', legend = None, 
                            title = 'Percentage of Data Scientist Job Ads with a Key Skill, ' + state)
        
    final_plot.set_ylabel('Percentage Appearing in Job Ads')
    fig = final_plot.get_figure() # Have to convert the pandas plot object to a matplotlib object
    jd = pd.DataFrame(job_descriptions)    
        
    return jd # End of the function

# %%
job_info = skills_info_ind(city = "Hyderabad", state = "Telangana")
# Out:
# http://www.indeed.co.in/jobs?q=%22data+scientist%22&l=Hyderabad%2C+Telangana
# b'\n                    Page 1 of 49 jobs'
# ['1', '49']
# There were 490 jobs found, Hyderabad
# Getting page 1
# ['http://www.indeed.co.in/rc/clk?jk=cefa1941febe77da&fccid=6c30ad86e1d040f4&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=161dbd8666fed38a&fccid=d0b991d272eb746a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=5cb8a75cff2ed06c&fccid=3fe48533ae9fe92d&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=1973ff5e0c80b165&fccid=6d4c89fef94a8c98&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=5a81c8c409bed19a&fccid=615c4f81c15600c4&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=d1d089668b2c4520&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=aeb0a30b2e438235&fccid=f6ce40c91e89f80b&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=475ce1dde7ff368a&fccid=84abc84ad22f88fe&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=76528ffad2487cc1&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=7d3b5f16eee15587&fccid=4111fd9205d57b0f&vjs=3']
# Getting page 2
# ['http://www.indeed.co.in/rc/clk?jk=d1d089668b2c4520&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=7f088e6582775fa1&fccid=bab1f51ac8a7faee&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=7d3b5f16eee15587&fccid=4111fd9205d57b0f&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=e7f34eb040332b71&fccid=7f3529af0fe98977&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=1973ff5e0c80b165&fccid=6d4c89fef94a8c98&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=cf127c481ac7b77f&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=99a0f030d373ec54&fccid=cd1c087ed0fcb7d8&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=77c7ea5867a52a5b&fccid=86b3cb7b9af3ee8e&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0f0dd8a7ec9f3125&fccid=c35194d01a9e2595&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=b9c0ebda601461c5&fccid=21df030fae150acc&vjs=3']
# Getting page 3
# ['http://www.indeed.co.in/rc/clk?jk=d08cd94e269de924&fccid=c35194d01a9e2595&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=42d486e850cdec94&fccid=e0efd5c38293090b&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=109280b30e961e7a&fccid=d0b991d272eb746a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=502704c08c9296af&fccid=a4e4e2eaf26690c9&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=dcf33e89390d00fb&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=1398147ffaaf489e&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3']
# Getting page 4
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 5
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 6
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 7
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 8
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 9
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 10
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 11
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 12
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 13
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 14
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 15
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 16
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 17
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 18
# ['http://www.indeed.co.in/rc/clk?jk=109280b30e961e7a&fccid=d0b991d272eb746a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=b9c0ebda601461c5&fccid=21df030fae150acc&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=dcf33e89390d00fb&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=1398147ffaaf489e&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 19
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 20
# ['http://www.indeed.co.in/rc/clk?jk=109280b30e961e7a&fccid=d0b991d272eb746a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=502704c08c9296af&fccid=a4e4e2eaf26690c9&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=dcf33e89390d00fb&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=1398147ffaaf489e&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 21
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 22
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 23
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 24
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 25
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 26
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 27
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 28
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 29
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 30
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 31
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 32
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 33
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 34
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 35
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 36
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 37
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 38
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 39
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 40
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 41
# ['http://www.indeed.co.in/rc/clk?jk=109280b30e961e7a&fccid=d0b991d272eb746a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=502704c08c9296af&fccid=a4e4e2eaf26690c9&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=dcf33e89390d00fb&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=1398147ffaaf489e&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 42
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 43
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 44
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 45
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# Getting page 46
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 47
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 48
# ['http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=3e060ff4255bc3d5&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3']
# Getting page 49
# ['http://www.indeed.co.in/rc/clk?jk=0d18908418825b55&fccid=5d3ed74ca4598964&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=9432e386f38dcc7c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=86d176c58e4a6b2a&fccid=55e0d29df429b371&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=ac9bb1ca7d99f182&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=eb688aa3261ea8b5&fccid=dd616958bd9ddc12&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4a94dd89a9e4be65&fccid=7ab93833a090100a&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=606344344864884c&fccid=6533b13eb116b689&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=6e033c0acc4b75cd&fccid=be240c643a8631c5&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=4cb1dbd5b17ad01b&fccid=b1e0f66da5c9df23&vjs=3', 'http://www.indeed.co.in/rc/clk?jk=23a20a86d43a8808&fccid=be240c643a8631c5&vjs=3']
# [['companiessalariesindeed', 'jobs', 'customers', 'including', 'inemployers', 'operational', 'keywords', 'deep', 'nowapply', 'description', 'doe', 'resume', 'find', 'help', 'analysis.', 'industry', 'companywherecity', 'updates', 'jobsadvanced', 'telanganatcpwave3', 'advicebrowse', 'research', 'indeedprivacy', 'here.salary', 'highly', 'build', 'dl', 'quantitative', 'telanganasenior', 'save', 'telanganajobs', 'hyderabad', 'libraries', 'experience', 'degree', 'able', 'whatjob', 'modelling', 'r', 'project', 'sql', 'tcpwave3', 'scikit', 'jobscompany', 'tensorflow', 'sitesave', 'data', 'sparkml.', 'skills', 'deliver', 'telangana', 'mlr', 'need.', 'problem', 'minimum', 'using', 'keras', 'models.', 'scientisttcpwave3', 'privacy', 'frameworks', 'business', 'reviewscareer', 'number', 'caffe', 'technical', 'ago', 'pin', 'predictive', 'ml', 'statistics', 'termslet', 'science', 'jobsenior', 'understanding', 'beginning', 'reviewsfind', 'working', 'salaries', 'post', 'jobsbrowse', 'jobapply', 'caret', 'bachelor', 'field', 'learning', 'indeed.com', 'tcpwave', 'giving', 'cntk', 'resumesign', 'codefind', 'mxnet', 'youupload', 'title', 'positions', 'days', 'centercookies', 'searchsenior', 'machine', 'infofollowget', 'end', 'gpus', 'eventswork', 'years', 'state', 'salariespost', 'computer', 'company', 'like', 'learn', 'etc.', 'jobis', 'senior', 'saying', 'presentations.tcpwave', 'use', 'employers', 'theano', 'job', 'develop', 'responsibilities', 'center', 'qualification', '+', 'original', 'reviews', 'telanganacompany', 'assist', '3', 'indeedabouthelp', 'mathematics', 'scientist', 'people', 'masters', 'reviewsread', 'python', 'mllib'], ['companiessalariesindeed', 'jobs', 'provide', 'organize', 'inemployers', 'solving', 'india', 'quality', 'interpreting', 'generation', 'one', 'keywords', 'petrochemicals', 'nowapply', 'industries', 'outcomes', 'background', 'analyzing', 'programming', 'point', 'find', 'good', 'consulting', 'resume', 'industry', 'tableau', 'management', 'companywherecity', 'team', 'risk', 'writing', 'outside', 'required', 'updates', 'space', 'jobsadvanced', 'complicated', 'datasets', 'advicebrowse', 'benchmarking.', 'need', 'research', 'within', 'indeedprivacy', 'powerpoint', 'significant', 'tools', 'build', 'extensively.', 'independently', 'large', 'ability', 'quantitative', 'reports', 'queries', 'dss', 'desired', 'chemical', 'save', 'telanganajobs', 'client', 'db', 'hyderabad', 'communicate', 'experience', 'short', 'software', 'durations', 'dashboards', 'requirements', 'jobdata', 'layers', 'solutionscareer', 'whatjob', 'modelling', 'r', 'sql', 'project', 'amounts', 'professional', 'application', 'design', 'jobscompany', 'detail', 'cleansing', 'analytical', 'added', 'web', 'data', 'skills', 'operations', 'oil', 'dimensionality', 'telangana', 'problem', 'chemicals', 'advantage.', 'manage', 'techniques', 'accuracy', 'write', 'mining', 'scripting', 'story', 'implementation', 'using', 'metals', 'analyst', 'javascript', 'html', 'handle', 'engagement', 'advanced', 'privacy', 'databases', 'analytics.', 'business', 'effectively', 'technical', 'ago', 'disseminate', 'pin', 'telanganadata', 'predictive', 'storytelling', 'embedded', 'nowsave', 'sustainable', 'statistics', 'termslet', 'information', 'skillsets', 'processes', 'regarding', 'understanding', 'dashboards.', 'bi', 'leading', 'reviewsfind', 'clearly', 'salaries', 'segmentation', 'preferably', 'findings', 'post', 'solutions', 'power', 'hadoop', 'jobsbrowse', 'advantage', 'jobapply', 'complex', 'visualization', 'report', 'ideas', 'collect', 'varying', 'development', 'preferred', 'adept', 'strong', 'coach', 'intelligence', 'statistical', 'indeed.com', 'database', 'packages', 'resumesign', 'codefind', 'models', 'python', 'youupload', 'title', 'building', 'reporting', 'days', 'centercookies', 'clients', 'must', 'open', 'verticals', 'languages', 'support', 'create', 'infofollowget', 'knowledge', 'end', 'eventswork', 'areas', 'plus', 'levels', 'travel', 'proven', 'troubleshoot', 'years', 'sta ...
# Done with collecting the job postings!
# There were 502 jobs successfully found.
# Counter({'Education': 236, 'Travel': 60, 'Healthcare': 47, 'Retail': 3, 'Telecom': 2, 'Banking': 1, 'Energy': 1, 'Aerospace': 0, 'Automobile': 0, 'FMCG': 0})
#          Term  NumPostings
# 0   Aerospace            0
# 1  Automobile            0
# 2     Banking            1
# 3        FMCG            0
# 4      Retail            3
# 5      Travel           60
# 6     Telecom            2
# 7  Healthcare           47
# 8      Energy            1
# 9   Education          236
# ****
#          Term  NumPostings
# 9   Education    47.011952
# 5      Travel    11.952191
# 7  Healthcare     9.362550
# 4      Retail     0.597610
# 6     Telecom     0.398406
# 2     Banking     0.199203
# 8      Energy     0.199203
# 0   Aerospace     0.000000
# 1  Automobile     0.000000
# 3        FMCG     0.000000
# Sai
